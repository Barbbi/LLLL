# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset=pd.read_csv('/content/drive/MyDrive/AMZN (1).csv')

# %%
dataset
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-12-05    0.221875    0.229688    0.217708    0.229688    0.229688
# 1     1997-12-08    0.227083    0.238542    0.226042    0.235417    0.235417
# 2     1997-12-09    0.233333    0.238542    0.230208    0.234375    0.234375
# 3     1997-12-10    0.229167    0.231250    0.219792    0.225521    0.225521
# 4     1997-12-11    0.219792    0.241667    0.219792    0.234375    0.234375
# ...          ...         ...         ...         ...         ...         ...
# 6468  2023-08-22  135.080002  135.649994  133.729996  134.250000  134.250000
# 6469  2023-08-23  134.500000  135.949997  133.220001  135.520004  135.520004
# 6470  2023-08-24  136.399994  136.779999  131.830002  131.839996  131.839996
# 6471  2023-08-25  132.470001  133.869995  130.580002  133.259995  133.259995
# 6472  2023-08-28  133.779999  133.949997  131.850006  133.139999  133.139999
#
#          Volume
# 0      53232000
# ...

# %%
dataset.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6473 entries, 0 to 6472
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6473 non-null   object
#  1   Open       6473 non-null   float64
#  2   High       6473 non-null   float64
#  3   Low        6473 non-null   float64
#  4   Close      6473 non-null   float64
#  5   Adj Close  6473 non-null   float64
#  6   Volume     6473 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 354.1+ KB

# %%
sns.distplot(dataset.High)
# Out:
# <Axes: xlabel='High', ylabel='Density'>

# %%
minmax = dataset.describe().T

# %%
minmax
# Out:
#             count          mean           std           min           25%  \
# Open       6473.0  3.368756e+01  4.929912e+01  2.083330e-01  2.117000e+00
# High       6473.0  3.409303e+01  4.987765e+01  2.192710e-01  2.159000e+00
# Low        6473.0  3.324460e+01  4.865691e+01  2.072920e-01  2.076500e+00
# Close      6473.0  3.367537e+01  4.926401e+01  2.130210e-01  2.120500e+00
# Adj Close  6473.0  3.367537e+01  4.926401e+01  2.130210e-01  2.120500e+00
# Volume     6473.0  1.423937e+08  1.393977e+08  9.744000e+06  6.881800e+07
#
#                     50%           75%           max
# Open       8.000500e+00  4.284750e+01  1.872000e+02
# High       8.060500e+00  4.292150e+01  1.886540e+02
# Low        7.850500e+00  4.255050e+01  1.848395e+02
# Close      7.968500e+00  4.278050e+01  1.865705e+02
# Adj Close  7.968500e+00  4.278050e+01  1.865705e+02
# Volume     1.056160e+08  1.602260e+08  2.086584e+09

# %%
copyofDataset=dataset[dataset.Date.between("2019-01-01", "2023-08-28")]

# %%
copyofDataset
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 5301  2019-01-02   73.260002   77.667999   73.046501   76.956497   76.956497
# 5302  2019-01-03   76.000504   76.900002   74.855499   75.014000   75.014000
# 5303  2019-01-04   76.500000   79.699997   75.915497   78.769501   78.769501
# 5304  2019-01-07   80.115501   81.727997   79.459503   81.475502   81.475502
# 5305  2019-01-08   83.234497   83.830498   80.830498   82.829002   82.829002
# ...          ...         ...         ...         ...         ...         ...
# 6468  2023-08-22  135.080002  135.649994  133.729996  134.250000  134.250000
# 6469  2023-08-23  134.500000  135.949997  133.220001  135.520004  135.520004
# 6470  2023-08-24  136.399994  136.779999  131.830002  131.839996  131.839996
# 6471  2023-08-25  132.470001  133.869995  130.580002  133.259995  133.259995
# 6472  2023-08-28  133.779999  133.949997  131.850006  133.139999  133.139999
#
#          Volume
# 5301  159662000
# ...

# %%
copyofDataset.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
copyofDataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1172 entries, 5301 to 6472
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1172 non-null   object
#  1   Open       1172 non-null   float64
#  2   High       1172 non-null   float64
#  3   Low        1172 non-null   float64
#  4   Close      1172 non-null   float64
#  5   Adj Close  1172 non-null   float64
#  6   Volume     1172 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 73.2+ KB

# %%
sns.distplot(copyofDataset.High)
# Out:
# <Axes: xlabel='High', ylabel='Density'>

# %%
result = pd.read_csv('/content/drive/MyDrive/result.csv')

# %%
result
# Out:
#    result__peerGroup  result__symbolSeries__timestamp  \
# 0          Retailing                       1409529600
# 1                NaN                       1412121600
# 2                NaN                       1414800000
# 3                NaN                       1417392000
# 4                NaN                       1420070400
# ..               ...                              ...
# 91               NaN                       1648771200
# 92               NaN                       1651363200
# 93               NaN                       1654041600
# 94               NaN                       1656633600
# 95               NaN                       1659312000
#
#     result__symbolSeries__esgScore  result__symbolSeries__governanceScore  \
# 0                            51.00                                  50.00
# 1                            51.00                                  50.00
# 2                            51.00                                  50.00
# ...

# %%
result.drop(["result__peerGroup","result__symbolSeries__timestamp","result__symbolSeries__governanceScore","result__symbolSeries__environmentScore","result__symbolSeries__socialScore","result__peerSeries__timestamp","result__peerSeries__governanceScore","result__peerSeries__environmentScore","result__peerSeries__socialScore","error"],axis= 1, inplace = True)

# %%
result
# Out:
#     result__symbolSeries__esgScore  result__peerSeries__esgScore
# 0                            51.00                     57.272727
# 1                            51.00                     57.357143
# 2                            51.00                     57.357143
# 3                            50.00                     57.267857
# 4                            50.00                     57.250000
# ..                             ...                           ...
# 91                             NaN                           NaN
# 92                           30.23                     16.393158
# 93                             NaN                           NaN
# 94                             NaN                           NaN
# 95                           30.28                     16.178148
#
# [96 rows x 2 columns]

# %%
resultT = result.fillna(0)

# %%
resultT
# Out:
#     result__symbolSeries__esgScore  result__peerSeries__esgScore
# 0                            51.00                     57.272727
# 1                            51.00                     57.357143
# 2                            51.00                     57.357143
# 3                            50.00                     57.267857
# 4                            50.00                     57.250000
# ..                             ...                           ...
# 91                            0.00                      0.000000
# 92                           30.23                     16.393158
# 93                            0.00                      0.000000
# 94                            0.00                      0.000000
# 95                           30.28                     16.178148
#
# [96 rows x 2 columns]

# %%
result.isnull().sum()
# Out:
# result__symbolSeries__esgScore    18
# result__peerSeries__esgScore      17
# dtype: int64

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   result__symbolSeries__esgScore  78 non-null     float64
#  1   result__peerSeries__esgScore    79 non-null     float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %%
# !pip install tsfresh
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 8.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from tsfresh import extract_features
from tsfresh.utilities.dataframe_functions import impute

# %%
copyofDataset['Date'] = pd.to_datetime(copyofDataset['Date'])
copyofDataset.set_index('Date', inplace=True)

# %%
y = copyofDataset['High']
X = y.copy()

# %%
X = extract_features(copyofDataset,
                     column_id="High",
                     pivot=False)
# Out:
# WARNING:tsfresh.feature_extraction.settings:Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 5710/5710 [02:52<00:00, 33.06it/s]

# %%
XX = extract_features(copyofDataset,
                     column_id="High",
                     pivot=True)
# Out:
# WARNING:tsfresh.feature_extraction.settings:Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 5710/5710 [02:34<00:00, 36.85it/s]

# %%
XY = extract_features(copyofDataset,
                     column_id="High",
                     column_value="Volume",
                     pivot=True)
# Out:
# WARNING:tsfresh.feature_extraction.settings:Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 1142/1142 [00:38<00:00, 29.42it/s]

# %%
impute(XY)
# Out:
#             Volume__variance_larger_than_standard_deviation  \
# 76.900002                                               0.0
# 77.667999                                               0.0
# 79.429497                                               0.0
# 79.699997                                               0.0
# 80.464500                                               0.0
# ...                                                     ...
# 187.399994                                              0.0
# 187.864502                                              0.0
# 187.999496                                              0.0
# 188.107498                                              0.0
# 188.654007                                              0.0
#
#             Volume__has_duplicate_max  Volume__has_duplicate_min  \
# 76.900002                         0.0                        0.0
# 77.667999                         0.0                        0.0
# ...

# %%
print(XX)
# Out:
#             Open__variance_larger_than_standard_deviation  \
# 76.900002                                             0.0
# 77.667999                                             0.0
# 79.429497                                             0.0
# 79.699997                                             0.0
# 80.464500                                             0.0
# ...                                                   ...
# 187.399994                                            0.0
# 187.864502                                            0.0
# 187.999496                                            0.0
# 188.107498                                            0.0
# 188.654007                                            0.0
#
#             Open__has_duplicate_max  Open__has_duplicate_min  \
# 76.900002                       0.0                      0.0
# 77.667999                       0.0                      0.0
# 79.429497                       0.0                      0.0
# ...

# %%
print(X)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
copyofDataset=dataset[dataset.Date.between("2019-01-01", "2023-08-28")]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(copyofDataset,  copyofDataset['High'], test_size=0.2)

# %%
X_train = copyofDataset[['Open', 'High', 'Low', 'Volume']].values
X_test = copyofDataset[['Open', 'High', 'Low', 'Volume']].values

# %%
Y_train = copyofDataset['High'].values
Y_test = copyofDataset['High'].values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(copyofDataset)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X = copyofDataset.iloc[:, 1:2].values
Y = copyofDataset.iloc[:, 2:3].values

X = scaler.fit_transform(X)
Y = scaler.fit_transform(Y)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
testing_r2 = r2_score(Y_test, y_pred)

# %%
print("r2 score for the dataset is: " + str(testing_r2))
# Out:
# r2 score for the dataset is: 1.0

# %%
from xgboost import XGBClassifier,cv,DMatrix,plot_tree

# %%
copyofDataset=dataset[dataset.Date.between("2019-01-01", "2023-08-28")]
copyofDataset
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 5301  2019-01-02   73.260002   77.667999   73.046501   76.956497   76.956497
# 5302  2019-01-03   76.000504   76.900002   74.855499   75.014000   75.014000
# 5303  2019-01-04   76.500000   79.699997   75.915497   78.769501   78.769501
# 5304  2019-01-07   80.115501   81.727997   79.459503   81.475502   81.475502
# 5305  2019-01-08   83.234497   83.830498   80.830498   82.829002   82.829002
# ...          ...         ...         ...         ...         ...         ...
# 6468  2023-08-22  135.080002  135.649994  133.729996  134.250000  134.250000
# 6469  2023-08-23  134.500000  135.949997  133.220001  135.520004  135.520004
# 6470  2023-08-24  136.399994  136.779999  131.830002  131.839996  131.839996
# 6471  2023-08-25  132.470001  133.869995  130.580002  133.259995  133.259995
# 6472  2023-08-28  133.779999  133.949997  131.850006  133.139999  133.139999
#
#          Volume
# 5301  159662000
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split( copyofDataset[copyofDataset.columns[:-1]],  copyofDataset['High'], test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()



X = scaler.fit_transform(X)
Y = scaler.fit_transform(Y)

# %%
X_trains = copyofDataset.drop('Date', axis=1, inplace=True)

# %%
classifier = XGBClassifier()

# %%
model = XGBClassifier(n_estimators=15,max_depth=15,learning_rate =0.01,min_child_weight=5,colsample_bytree=0.3)

# %%
copyofDataset['High'] = copyofDataset['High'].astype(int)

# %%
copyofDataset['Low'] = copyofDataset['Low'].astype(int)

# %%
copyofDataset['Open'] = copyofDataset['Open'].astype(int)

# %%
copyofDataset['Close'] = copyofDataset['Close'].astype(int)

# %%
copyofDataset['Adj Close'] = copyofDataset['Adj Close'].astype(int)

# %%
resultT['result__symbolSeries__esgScore'] = resultT['result__symbolSeries__esgScore'].astype(int)

# %%
resultT['result__peerSeries__esgScore'] = resultT['result__peerSeries__esgScore'].astype(int)

# %%
resultT
# Out:
#     result__symbolSeries__esgScore  result__peerSeries__esgScore
# 0                               51                            57
# 1                               51                            57
# 2                               51                            57
# 3                               50                            57
# 4                               50                            57
# ..                             ...                           ...
# 91                               0                             0
# 92                              30                            16
# 93                               0                             0
# 94                               0                             0
# 95                              30                            16
#
# [96 rows x 2 columns]

# %%
copyofDataset
# Out:
#       Open  High  Low  Close  Adj Close     Volume
# 5301    73    77   73     76         76  159662000
# 5302    76    76   74     75         75  139512000
# 5303    76    79   75     78         78  183652000
# 5304    80    81   79     81         81  159864000
# 5305    83    83   80     82         82  177628000
# ...    ...   ...  ...    ...        ...        ...
# 6468   135   135  133    134        134   32935100
# 6469   134   135  133    135        135   42801000
# 6470   136   136  131    131        131   43646300
# 6471   132   133  130    133        133   44124800
# 6472   133   133  131    133        133   34083100
#
# [1172 rows x 6 columns]

# %%
Y_train = pd.DataFrame(Y_train,columns=result.drop(['result__peerSeries__esgScore'],axis=1).columns)

# %%
X_train = pd.DataFrame(X_train,columns=copyofDataset.drop(['High'],axis=1).columns)

# %%
from xgboost import XGBClassifier,cv,DMatrix,plot_tree

# %%
model.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-255-f526595d08c3> in <cell line: 1>()
# ----> 1 model.fit(X_train, Y_train)
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1469                 xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1470             )
# -> 1471             train_dmatrix, evals = _wrap_evaluation_matrices(
# ...
